# %% [markdown]
# # API Research (r34)
#
# This notebook explores the data structure returned by the API.

# %%
import requests
import pandas as pd
import json
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %% [markdown]
# Let's find how much tags are there.

# %%
import requests
import xml.etree.ElementTree as ET

def check_page_exists(page):
    """Checks if a page exists for a given ID using the Rule34 API."""
    credentials = os.getenv('R34_ACCESS_CREDENTIALS')
    url = f"https://api.rule34.xxx/index.php?page=dapi&s=tag&q=index&pid={page}&limit=1000"
    try:
        response = requests.get(f"{url}{credentials}", timeout=10)
        root = ET.fromstring(response.content)
        return len(root.findall('tag')) > 0
    except Exception:
        return False


def find_total_tag_pages(low=1000, high=3000):
    """Performs a binary search to find the highest valid tag ID."""
    result = low
    while low <= high:
        mid = (low + high) // 2
        print(f"Probing ID: {mid}...", end="\r")
        if check_page_exists(mid):
            result = mid
            low = mid + 1
        else:
            high = mid - 1
    return result

total_tag_pages = find_total_tag_pages()
print(f"\nApproximate total tags (highest ID): {total_tags}")
# Out:
# Probing ID: 1248...
# Approximate total tags (highest ID): 1248

# %% [markdown]
# Each we have to get

# %%
pd.read_csv('../data/r34data/rule34_tags.csv')
# Out:
#       3  2         kogurein  False   12668  0
# 0     4  1      noki_welkin   True   19899  0
# 1     4  1      norita_mado  False   20127  0
# 2     4  1    kyrie_(quilt)   True   20163  0
# 3     1  1         kyomachi   True   20171  0
# 4     1  1           olinca   True   20228  0
# ...  .. ..              ...    ...     ... ..
# 9995  0  1  shinonome_houki  False  107491  9
# 9996  1  1        meet_neet  False  107493  9
# 9997  0  1    male_mikhalia  False  107498  9
# 9998  1  1        tihapitan  False  107553  9
# 9999  0  1     takeo_takumi  False  107562  9
#
# [10000 rows x 6 columns]

# %%
df = pd.DataFrame()
credentials = os.getenv('R34_ACCESS_CREDENTIALS')
for i in range(total_tag_pages):
    try:
        if i in pd.read_csv('../data/r34data/rule34_tags.csv', usecols=['page'])['page'].values:
            continue
    except:
        pass
    url = f"https://api.rule34.xxx/index.php?page=dapi&s=tag&q=index&pid={i}&limit=1000"
    response = requests.get(f"{url}{credentials}", timeout=10)
    df = pd.read_xml(response.text)
    df['page'] = i
    if i == 0:
        df.to_csv('../data/r34data/rule34_tags.csv', mode='w', index=False, header=True)
    else:
        df.to_csv('../data/r34data/rule34_tags.csv', mode='a', index=False, header=False)
# Out:
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
# /tmp/ipykernel_8678/1262958322.py:11: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)

# %%
# Out:
# False
# 0

# %%
print(root.findall('tag'))
# Out:
# [<Element 'tag' at 0x7ff37a321c10>, <Element 'tag' at 0x7ff37a41b830>, <Element 'tag' at 0x7ff37a4193a0>, <Element 'tag' at 0x7ff3b5569850>, <Element 'tag' at 0x7ff36bdbaca0>, <Element 'tag' at 0x7ff36bdbbc40>, <Element 'tag' at 0x7ff36bdba340>, <Element 'tag' at 0x7ff36bdbb380>, <Element 'tag' at 0x7ff36bdb8950>, <Element 'tag' at 0x7ff36bdba3e0>, <Element 'tag' at 0x7ff36bd7b100>, <Element 'tag' at 0x7ff36bd7b060>, <Element 'tag' at 0x7ff36bd7acf0>, <Element 'tag' at 0x7ff36bd7be20>
a3e0>, <Element 'tag' at 0x7ff36bd7a430>, <Element 'tag' at 0x7ff36bd7a5c0>, <Element 'tag' at 0x7ff36bd7a610>, <Element 'tag' at 0x7ff36bd7a660>, <Element 'tag' at 0x7ff36bd7a6b0>, <Element 'tag' at 0x7ff36bd795d0>, <Element 'tag' at 0x7ff36bd79620>, <Element 'tag' at 0x7ff36bd796c0>, <Element 'tag' at 0x7ff36bd79710>, <Element 'tag' at 0x7ff36bd79440>, <Element 'tag' at 0x7ff36bd79490>, <Element 'tag' at 0x7ff36bd794e0>, <Element 'tag' at 0x7ff36bd79530>, <Element 'tag' at 0x7ff36bd79580>, <Element 'tag' at 0x7ff36bd793a0>, <Element 'tag' at 0x7ff36bd78f90>, <Element 'tag' at 0x7ff36bd79350>, <Element 'tag' at 0x7ff36bd793f0>, <Element 'tag' at 0x7ff36bd79260>, <Element 'tag' at 0x7ff36bd79300>, <Element 'tag' at 0x7ff36bd79120>, <Element 'tag' at 0x7ff36bd79210>, <Element 'tag' at 0x7ff36bd792b0>, <Element 'tag' at 0x7ff36bd78040>, <Element 'tag' at 0x7ff36bd780e0>, <Element 'tag' at 0x7ff36bd78130>, <Element 'tag' at 0x7ff36bd78180>, <Element 'tag' at 0x7ff36bd781d0>, <Element 'tag' at 0x7ff36bd78220>, <Element 'tag' at 0x7ff36bd78270>, <Element 'tag' at 0x7ff36bd784f0>, <Element 'tag' at 0x7ff36bd78770>, <Element 'tag' at 0x7ff36bd78900>, <Element 'tag' at 0x7ff36bd789a0>, <Element 'tag' at 0x7ff36bd789f0>, <Element  ...

# %%
# Setting up the base URL
url = "https://api.rule34.xxx/index.php?page=dapi&s=tag&q=index"
credentials = os.getenv('R34_ACCESS_CREDENTIALS')
limit = 100

# %%
response = requests.get(f"{url}{credentials}&limit={limit}", timeout=10)

# %%
df = pd.read_xml(response.text)
df
# Out:
# /tmp/ipykernel_8678/3402715580.py:1: FutureWarning: Passing literal xml to 'read_xml' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_xml(response.text)
#     type  count                       name  ambiguous     id
# 0      3      2                   kogurein      False  12668
# 1      4      1                noki_welkin       True  19899
# 2      4      1                norita_mado      False  20127
# 3      4      1              kyrie_(quilt)       True  20163
# 4      1      1                   kyomachi       True  20171
# ..   ...    ...                        ...        ...    ...
# 95     1      1               hitode_jinbo      False  23048
# 96     4      3                    gallico      False  16190
# 97     1      1               kurubusi-kai      False  23082
# 98     1      1                   enueichi      False  23083
# 99     4      1  hien_(ne~pon?_x_rai_pon!)      False  23122
#
# [100 rows x 5 columns]

# %%
df.sort_values(by='count', ascending=False)
# Out:
#      type  count              name  ambiguous     id
# 968     0     20  fighters_gigamix      False  45560
# 873     1     20    also_anonymous      False  42582
# 618     3     20    hot_shots_golf      False  31361
# 881     4     19      akito_hayama      False  42976
# 882     4     19     tsuyoshi_ohki      False  42982
# ..    ...    ...               ...        ...    ...
# 466     0      1     brachy_pelman      False  33358
# 467     4      1   flare_en_kuldes      False  33424
# 120     5      1   inatsuki_nanami      False  23819
# 119     4      1    gokokuji_marie      False  23781
# 456     1      1           hikaeme      False  33218
#
# [1000 rows x 5 columns]
